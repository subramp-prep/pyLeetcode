# %% [markdown]
# ## 872 Leaf-Similar Trees
#
# Consider all the leaves of a binary tree.  From left to right order, the values of those leaves form a leaf value sequence.
#
# ![872.png](attachment:872.png)
#
#
# For example, in the given tree above, the leaf value sequence is (6, 7, 4, 9, 8).
#
# Two binary trees are considered leaf-similar if their leaf value sequence is the same.
#
# Return true if and only if the two given trees with head nodes root1 and root2 are leaf-similar.
#
#
#
# Constraints:
#
# Both of the given trees will have between 1 and 200 nodes.
# Both of the given trees will have values between 0 and 200

# %%
class TreeNode:
    def __init__(self, val, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def buildTree(nums, index, root):
    if index < len(nums) and nums[index]:
        root = TreeNode(nums[index])
        root.left = buildTree(nums, 2*index+1, root.left)
        root.right = buildTree(nums, 2*index+2, root.right)
        
        return root

def leafSimilar(root1, root2):
    def getLeafNodes(root):
        output = []

        def helper(head):
            if head:
                if not head.left and not head.right:
                    output.append(head.val)

                helper(head.left)
                helper(head.right)

        helper(root)
        return output

    return getLeafNodes(root1) == getLeafNodes(root2)

# %%
n1 = [3,5,1,6,2,9,8,None,None,7,4]
n2 = [3,5,1,6,7,4,2,None,None,None,None,None,None,9,8]

print(leafSimilar(buildTree(n1, 0, None), buildTree(n2, 0, None)))
# Out:
# True
